# %% [markdown]
# # 📈 Task 2.5: Term Lifecycle Analysis (Paper Replication)
#
# **Objective**: Replicate the "Dartmouth Term Lifecycle" findings from the StudentLife paper (Figure 5). We expect to see:
# - **Stress**: Increasing trend, peaking at finals.
# - **Sleep**: Decreasing trend.
# - **Conversation**: Decreasing trend.
#
# ## 1. Setup & Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

sns.set_theme(style="whitegrid")
DATA_DIR = Path("../../data/raw/dataset")

# %% [markdown]
# ## 2. Define Term Timeline
# **Start Date**: March 2013 (Week 1)
# **End Date**: June 2013 (Week 10)
# **Key Periods**:
# - Weeks 1-3: Start of term
# - Weeks 4-7: Midterms
# - Weeks 8-10: Finals

# %%
# TODO: Create date range for the term

# %% [markdown]
# ## 3. Replicate Figure 5 (Trends)
# **Metrics to Plot**:
# - Daily Stress (EMA)
# - Daily Sleep Duration (EMA + Sensor)
# - Daily Conversation Duration (Sensor)
#
# **Method**: Calculate daily population mean and plot with 7-day rolling average.

# %%
# TODO: Load data, aggregate by day, plot trends
